# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Sample - Superstore.csv',encoding='latin1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 4864    4865  CA-2017-163531   6/26/2017  6/30/2017  Standard Class
# 6461    6462  US-2017-133361   5/14/2017  5/17/2017     First Class
# 4279    4280  US-2016-107440   4/16/2016  4/20/2016  Standard Class
# 2088    2089  CA-2016-140501   6/23/2016  6/28/2016  Standard Class
# 8671    8672  US-2014-159611  12/27/2014   1/1/2015    Second Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 4864    SC-20725  Steven Cartwright   Consumer  United States  New York City
# 6461    AJ-10780     Anthony Jacobs  Corporate  United States      Baltimore
# 4279    BS-11365       Bill Shonely  Corporate  United States       Lakewood
# 2088    IM-15070       Irene Maddox   Consumer  United States  New York City
# 8671    KB-16315         Karl Braun   Consumer  United States      Cleveland
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.describe(include='all')
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994       9994        9994            9994
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
df.corr(numeric_only=True)
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
df.sort_values(by='Sales')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4101    4102  US-2017-102288   6/19/2017   6/23/2017  Standard Class
# 9292    9293  CA-2017-124114    3/2/2017    3/2/2017        Same Day
# 8658    8659  CA-2016-168361   6/21/2016   6/25/2016  Standard Class
# 4711    4712  CA-2014-112403   3/31/2014   3/31/2014        Same Day
# 2106    2107  US-2014-152723   9/26/2014   9/26/2014        Same Day
# ...      ...             ...         ...         ...             ...
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
df.memory_usage()
# Out:
# Index              128
# Row ID           79952
# Order ID         79952
# Order Date       79952
# Ship Date        79952
# Ship Mode        79952
# Customer ID      79952
# Customer Name    79952
# Segment          79952
# Country          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Product ID       79952
# Category         79952
# Sub-Category     79952
# Product Name     79952
# Sales            79952
# Quantity         79952
# Discount         79952
# Profit           79952
# dtype: int64

# %%
df.select_dtypes(include='object')
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.iloc[:,0]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 9989    9990
# 9990    9991
# 9991    9992
# 9992    9993
# 9993    9994
# Name: Row ID, Length: 9994, dtype: int64

# %%
df.iloc[0]
# Out:
# Row ID                                           1
# Order ID                            CA-2016-152156
# Order Date                               11/8/2016
# Ship Date                               11/11/2016
# Ship Mode                             Second Class
# Customer ID                               CG-12520
# Customer Name                          Claire Gute
# Segment                                   Consumer
# Country                              United States
# City                                     Henderson
# State                                     Kentucky
# Postal Code                                  42420
# Region                                       South
# Product ID                         FUR-BO-10001798
# Category                                 Furniture
# Sub-Category                             Bookcases
# Product Name     Bush Somerset Collection Bookcase
# Sales                                       261.96
# ...

# %%
df.count()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
df_dirty=df.copy()

# %%
df_dirty.loc[0:10, 'Sales'] = None

# %%
df_dirty = pd.concat([df_dirty, df_dirty.iloc[0:5]])

# %%
df_dirty.columns = df_dirty.columns.str.upper() + " "

# %%
df_dirty['REGION '] = df_dirty['REGION '].str.upper()

# %%
df_dirty['CATEGORY '] = df_dirty['CATEGORY '].str.upper()

# %%
df_dirty.head()
# Out:
#    ROW ID        ORDER ID  ORDER DATE   SHIP DATE       SHIP MODE   \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
#
#   CUSTOMER ID    CUSTOMER NAME    SEGMENT        COUNTRY             CITY   \
# 0     CG-12520      Claire Gute   Consumer  United States        Henderson
# 1     CG-12520      Claire Gute   Consumer  United States        Henderson
# 2     DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3     SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4     SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ... POSTAL CODE   REGION       PRODUCT ID         CATEGORY  SUB-CATEGORY   \
# ...

# %%
# Check duplicate rows
df_dirty.duplicated().sum()
# Out:
# np.int64(5)

# %%
df_dirty.columns = (
    df_dirty.columns
    .str.strip()          # remove extra spaces
    .str.lower()          # lowercase
    .str.replace(' ', '_') # replace spaces with underscore
)

# %%
df_dirty.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# ...

# %%
df_dirty.isnull().sum()
# Out:
# row_id            0
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_id       0
# customer_name     0
# segment           0
# country           0
# city              0
# state             0
# postal_code       0
# region            0
# product_id        0
# category          0
# sub-category      0
# product_name      0
# sales            16
# quantity          0
# discount          0
# profit            0
# dtype: int64

# %%
df_dirty.fillna(df_dirty.mean(numeric_only=True), inplace=True)

# %%
df_dirty.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# ...

# %%
df_dirty.duplicated().sum()
# Out:
# np.int64(5)

# %%
df_dirty.drop_duplicates(inplace=True)

# %%
df_dirty.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_dirty.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# ...

# %%
df_dirty['region'] = df_dirty['region'].str.lower()

# %%
df_dirty.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df[['Sales', 'Profit', 'Discount']].mean()
# Out:
# Sales       229.858001
# Profit       28.656896
# Discount      0.156203
# dtype: float64

# %%
df[['Sales', 'Profit', 'Discount']].median()
# Out:
# Sales       54.4900
# Profit       8.6665
# Discount     0.2000
# dtype: float64

# %%
df[['Sales', 'Profit', 'Discount']].min()
# Out:
# Sales          0.444
# Profit     -6599.978
# Discount       0.000
# dtype: float64

# %%
df[['Sales', 'Profit', 'Discount']].max()
# Out:
# Sales       22638.480
# Profit       8399.976
# Discount        0.800
# dtype: float64

# %%
df.groupby('Category')[['Sales', 'Profit', 'Discount']].mean()
# Out:
#                       Sales     Profit  Discount
# Category
# Furniture        349.834887   8.699327  0.173923
# Office Supplies  119.324101  20.327050  0.157285
# Technology       452.709276  78.752002  0.132323

# %%
df.groupby('Segment')[['Sales', 'Profit', 'Discount']].mean()
# Out:
#                   Sales     Profit  Discount
# Segment
# Consumer     223.733644  25.836873  0.158141
# Corporate    233.823300  30.456667  0.158228
# Home Office  240.972041  33.818664  0.147128

# %%
df.groupby('Region')[['Sales', 'Profit', 'Discount']].mean()
# Out:
#               Sales     Profit  Discount
# Region
# Central  215.772661  17.092709  0.240353
# East     238.336110  32.135808  0.145365
# South    241.803645  28.857673  0.147253
# West     226.493233  33.849032  0.109335

# %%
df['Segment'].value_counts(normalize=True) * 100
# Out:
# Segment
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: proportion, dtype: float64

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].mode()
# Out:
# 0    Consumer
# Name: Segment, dtype: object

# %%
df['Sales'].std()
# Out:
# np.float64(623.2451005086807)

# %%
df['Sales'].var()
# Out:
# np.float64(388434.4553080756)

# %%
df.groupby(['Segment','Category'])['Sales'].mean()
# Out:
# Segment      Category
# Consumer     Furniture          351.347091
#              Office Supplies    116.390194
#              Technology         427.339534
# Corporate    Furniture          354.519792
#              Office Supplies    126.745309
#              Technology         444.855810
# Home Office  Furniture          336.825131
#              Office Supplies    115.309021
#              Technology         535.976658
# Name: Sales, dtype: float64

# %%
df.groupby('Segment')['Sales'].agg(['mean','max','min'])
# Out:
#                    mean       max    min
# Segment
# Consumer     223.733644  13999.96  0.444
# Corporate    233.823300  17499.95  0.556
# Home Office  240.972041  22638.48  0.990

# %%
df.groupby('Segment')['Sales'].mean().sort_values(ascending=False)
# Out:
# Segment
# Home Office    240.972041
# Corporate      233.823300
# Consumer       223.733644
# Name: Sales, dtype: float64

# %%
df_dirty['region'].value_counts().plot(kind='pie', autopct='%1.1f%%')

plt.title("Region Percentage")
plt.ylabel('')

plt.show()

# %%
df_dirty['sales'].plot(kind='hist')

plt.title("Sales Distribution")

plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x=df_dirty['sales'])

plt.title("Boxplot of Sales")

plt.show()

# %%
df_dirty.groupby('category')['sales'].mean().plot(kind='line')

plt.title("Average Sales by Category")

plt.show()

# %%
df_dirty['category'].value_counts().plot(kind='bar')

plt.title("Count of Categories")
plt.xlabel("Category")
plt.ylabel("Count")

plt.show()

# %%
df_dirty.plot(kind='scatter', x='sales', y='profit')

plt.title("Sales vs Profit")

plt.show()

# %%
sns.heatmap(
    df_dirty[['sales','profit','discount','quantity']].corr(),
    annot=True,
    cmap='coolwarm'
)

plt.show()

# %%
sns.countplot(x='segment', data=df_dirty)

plt.title("Orders per Segment")

plt.show()

# %%
columns = df_dirty[['sales', 'profit', 'discount']]

sns.pairplot(columns)

plt.show()

# %%
df_dirty.describe()
# Out:
#             row_id   postal_code         sales     quantity     discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.631325     3.789574     0.156203
# std    2885.163629  32063.693350    622.951921     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.285000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.780000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.984250     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df_dirty['category'].value_counts()
# Out:
# category
# OFFICE SUPPLIES    6026
# FURNITURE          2121
# TECHNOLOGY         1847
# Name: count, dtype: int64

# %%
df_dirty[['sales','profit','discount','quantity']].mean()
# Out:
# sales       229.631325
# profit       28.656896
# discount      0.156203
# quantity      3.789574
# dtype: float64

# %%
df_dirty[['sales','profit','discount','quantity']].median()
# Out:
# sales       54.7800
# profit       8.6665
# discount     0.2000
# quantity     3.0000
# dtype: float64

# %%
df_dirty[['sales','profit','discount','quantity']].max()
# Out:
# sales       22638.480
# profit       8399.976
# discount        0.800
# quantity       14.000
# dtype: float64

# %%
df_dirty.groupby('category')[['sales','profit','discount','quantity']].mean()
# Out:
#                       sales     profit  discount  quantity
# category
# FURNITURE        348.628680   8.699327  0.173923  3.785007
# OFFICE SUPPLIES  119.485150  20.327050  0.157285  3.801195
# TECHNOLOGY       452.342454  78.752002  0.132323  3.756903

# %%
df_dirty.groupby('region')['sales'].mean()
# Out:
# region
# central    215.772661
# east       238.336110
# south      241.152213
# west       226.115437
# Name: sales, dtype: float64

# %%
#Region-wise Sales
df_dirty.groupby('region')['sales'].mean()
# Out:
# region
# central    215.772661
# east       238.336110
# south      241.152213
# west       226.115437
# Name: sales, dtype: float64

# %%
#Segment-wise Profit
df_dirty.groupby('segment')['profit'].mean()
# Out:
# segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: profit, dtype: float64

# %%
#Average Sales by Category
df.groupby('Category')['Sales'].mean().plot(kind='bar')

plt.title('Average Sales by Category')
plt.ylabel('Sales')
plt.show()

# %%
#Average Profit by Category
df.groupby('Category')['Profit'].mean().plot(kind='bar')

plt.title('Average Profit by Category')
plt.ylabel('Profit')
plt.show()

# %%
#Average Sales by Region
df.groupby('Region')['Sales'].mean().plot(kind='bar')

plt.title('Average Sales by Region')
plt.ylabel('Sales')
plt.show()

# %%
df.corr(numeric_only=True)
